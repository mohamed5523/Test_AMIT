# %% [markdown]
# # Looping and Conditions

# %% [markdown]
# ## Conditions

# %% [markdown]
# ### Adult Check

# %% [markdown]
# ### Password Check

# %% [markdown]
# ### Break and Continue

# %% [markdown]
# ### Menu Choice

# %% [markdown]
# ## Looping

# %% [markdown]
# ### Fruits

# %% [markdown]
# ### Even & Odd

# %% [markdown]
# ### Range Function

# %% [markdown]
# ### Multiplication Table

# %% [markdown]
# ### Timer Sumtraction

# %% [markdown]
# ### Total of the list and append it to another list

# %% [markdown]
# ## Tasks

# %% [markdown]
# ### Guess the number

# %% [markdown]
# ### Calculator Game

# %% [markdown]
# ### ID and Age with Zip

# %% [markdown]
# ### I need this result

# %% [markdown]
# ![image.png](attachment:image.png)
