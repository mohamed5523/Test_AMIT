# %% [markdown]
# # Student Card

# %% [markdown]
# # Odd Even Check

# %% [markdown]
# # Guess Game

# %% [markdown]
# # Student Score Game

# %%
# student_number = int(input("Enter the number of students: "))

# students = []
# grades = []
# statuses = []

# for i in range(1, student_number + 1):
#     name = input(f"Enter the name of student {i}: ")
#     grade = float(input(f"Enter the grade of {name} (0-100): "))
#     students.append(name)
#     grades.append(grade)
#     statuses.append("PASS" if grade >= 60 else "FAIL")

# # ---------- Analysis ----------
# passed = statuses.count("PASS")
# failed = statuses.count("FAIL")

# average = sum(grades) / student_number if student_number else 0

# highest = max(grades)
# lowest = min(grades)
# top_student = students[grades.index(highest)]
# weakest_student = students[grades.index(lowest)]

# if average >= 85:
#     class_result = "Excellent"
# elif average >= 70:
#     class_result = "Very Good"
# elif average >= 60:
#     class_result = "Good"
# else:
#     class_result = "Needs Improvement"

# # ---------- Report ----------
# print("\n--- Final Analysis ---")

# for name, grade, status in zip(students, grades, statuses):
#     print(f"{name}: {grade} -> {status}")

# print(f"Class average: {round(average, 2)}")
# print(f"Highest: {top_student} ({highest})")
# print(f"Lowest: {weakest_student} ({lowest})")
# print(f"Passed: {passed}")
# print(f"Failed: {failed}")
# print(f"Overall performance: {class_result}")













student_number=int(input("Enter the number of student:"))
students=[]
grades=[]
for i in range(student_numvber)

# %% [markdown]
# # Divide Game and Astric Game and Alphapet Game

# %% [markdown]
# # Electricity	Bill Calculator

# %% [markdown]
# # Caluclator Game

# %%
num1=float(input("Enter first num:"))
oper=input("Enter opperation")
num2=float(input("Enter the second"))
if oper == "+":
    result=num1+num2
elif oper == "-":
    result=num1 - num2
elif oper== "/":
    if num2 ==0:
        print("Invalid")
    else:
        result=num1 /num2 
elif oper == "%":
    if num2 == 0:
        print("invalid")

    else:
       result= num1 % num2 
else:
    print("invalid oper")


print("Number", num1)
print("Oper", oper)
print("Number",num2)
print("Result",result)

# %% [markdown]
# # Application of naming the months from numbers into names

# %% [markdown]
# # Hello Function

# %% [markdown]
# # Info Function

# %% [markdown]
# # Sum , Sub , Multi Functions

# %% [markdown]
# # Absolute Function

# %% [markdown]
# # Minimum Function

# %% [markdown]
# # Circle Area Function

# %% [markdown]
# # Lambda Function Summation

# %% [markdown]
# # Lmabda Function Mapping

# %% [markdown]
# ## 3. Methods

# %% [markdown]
# # Maximum Function for 3 numbers

# %% [markdown]
# # Triangle Area Function

# %%
def passCheck(password):
    if password >=8:
        print("valid")
    for ch in password:
        upperch=False
        lowerch=False
        digitch=False
        specialch=False
        if ch.isupper():
            upperch=True
        if ch.islower():
            lowerch=True
        if ch.isdigit():
            digitch=True
        if not ch.isalnum():
            specialch=True
    else:
        print("not valid")

# %%
passCheck("")
